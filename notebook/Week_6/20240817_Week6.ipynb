# %% [markdown]
# # 17/08/2024 - Week 6
# ### Model Deployment

# %%
import streamlit as st

x = st.slider("Select a value")
st.write(x , "\nSquare value:",x*x)

# !streamlit run .\20240817_Week6.py
# Out:
# ^C
